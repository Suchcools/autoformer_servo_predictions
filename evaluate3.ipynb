# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
nums = 100

# %%
metrics=np.load('./results/dataset3_Autoformer_custom_ftM_sl7_ll7_pl1_dm512_nh8_el1_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/metrics.npy')
pred=np.load('./results/dataset3_Autoformer_custom_ftM_sl7_ll7_pl1_dm512_nh8_el1_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/pred.npy')
true=np.load('./results/dataset3_Autoformer_custom_ftM_sl7_ll7_pl1_dm512_nh8_el1_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/true.npy')
# 定义 Groundtruth 和 Predict 数据
gt = np.squeeze(true, axis=1)
pred = np.squeeze(pred, axis=1)

plt.plot([x[0] for x in gt[:nums]], c='b',label='一号舵机真实值')
plt.plot([x[0] for x in pred[:nums]],c='g',label='一号舵机预测值')


# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
plt.plot([x[1] for x in gt[:nums]], c='b',label='二号舵机真实值')
plt.plot([x[1] for x in pred[:nums]],c='g',label='二号舵机预测值')

# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
plt.plot([x[2] for x in gt[:nums]], c='b',label='三号舵机真实值')
plt.plot([x[2] for x in pred[:nums]],c='g',label='三号舵机预测值')
# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
nums = 10009

# %%
plt.plot([x[3] for x in gt[:nums]], c='b',label='四号舵机真实值')
plt.plot([x[3] for x in pred[:nums]],c='g',label='四号舵机预测值')

# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
gt.shape
# Out:
# (10272, 7)

# %%
pred.shape
# Out:
# (10272, 7)

# %%
metrics=np.load('./results/creep_Autoformer_custom_ftM_sl7_ll7_pl1_dm512_nh8_el1_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/metrics.npy')
pred=np.load('./results/creep_Autoformer_custom_ftM_sl7_ll7_pl1_dm512_nh8_el1_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/pred.npy')
true=np.load('./results/creep_Autoformer_custom_ftM_sl7_ll7_pl1_dm512_nh8_el1_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0/true.npy')
# 定义 Groundtruth 和 Predict 数据
# 定义 Groundtruth 和 Predict 数据
gt = np.squeeze(true, axis=1)[-100:]
pred = np.squeeze(pred, axis=1)[-100:]

plt.plot([x[2] for x in gt], c='b',label='Y1 GrundTruth')
plt.plot([x[2] for x in pred],c='g',label='Y1 Predict')

# plt.plot([x[1] for x in gt], c='r',label='Y2 GrundTruth')
# plt.plot([x[1] for x in pred],c='y',label='Y2 Predict')

# plt.plot([x[2] for x in gt], c='c',label='Y3 GrundTruth')
# plt.plot([x[2] for x in pred],c='m',label='Y3 Predict')

# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
plt.plot([x[1] for x in gt], c='r',label='Y2 GrundTruth')
plt.plot([x[1] for x in pred],c='y',label='Y2 Predict')

# plt.plot([x[2] for x in gt], c='c',label='Y3 GrundTruth')
# plt.plot([x[2] for x in pred],c='m',label='Y3 Predict')

# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
# plt.plot([x[1] for x in gt], c='r',label='Y2 GrundTruth')
# plt.plot([x[1] for x in pred],c='y',label='Y2 Predict')

plt.plot([x[0] for x in gt], c='c',label='Y3 GrundTruth')
plt.plot([x[0] for x in pred],c='m',label='Y3 Predict')

# 添加图例和标签
plt.legend(loc='best',fontsize=12)
plt.xlabel('Step',size=15)
plt.ylabel('Value',size=15)
plt.show()

# %%
me = pd.DataFrame(data=metrics,index=['mae', 'mse', 'rmse', 'mape', 'mspe']).T
me
# Out:
#        mae       mse      rmse      mape       mspe
# 0  0.21427  0.229816  0.479391  1.377218  58.173206
